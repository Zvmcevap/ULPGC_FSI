# %% [markdown]
# # ULPGC FSI Assignment
#
# Creating a computer vision model with keras
#
# Dataset is from https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip
#
# However I will only use the first 1000 images of each animal type because my laptop is not strong enough

# %% [markdown]
# #### Importing all the package requirements
#
# - numpy (everything needs numpy)
# - tensorflow (should also contain keras)
# - matplotlib to visualize the data

# %%
# !pip install numpy tensorflow matplotlib pydot

# %%
import os
import numpy as np
import keras
from keras import layers
import tensorflow as tf
from tensorflow import data as tf_data
import matplotlib.pyplot as plt

# %% [markdown]
# #### Filter out corrupted images
#
# The ones that do not contain JFIF in the header

# %%
num_skipped = 0
for folder_name in ("Cat", "Dog"):
    folder_path = os.path.join("PetImages", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = b"JFIF" in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print(f"Deleted {num_skipped} images.")
# Out:
# Deleted 0 images.

# %% [markdown]
# #### Creating the two datasets
#
# - train_ds for training data
# - val_ds for validation data

# %%
image_size = (180, 180)
batch_size = 128

train_ds, val_ds = keras.utils.image_dataset_from_directory(
    "PetImages",
    validation_split=0.2,
    subset="both",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 1879 files belonging to 2 classes.
# Using 1504 files for training.
# Using 375 files for validation.

# %% [markdown]
# #### Visualizing

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %% [markdown]
# #### Transformin images
#
# Apparently it is good practice to change the images a bit with rotations and mirroring

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
]


def data_augmentation(images):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images

plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")
# Out:
# WARNING:tensorflow:From C:\Users\zupan\miniconda3\envs\ULPGC_FSI\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# #### Cat in multiple rotations

# %% [markdown]
# #### Preprocessing data for CPU optimisation
#
# as the gpu isnt working well on my laptop

# %%
augmented_train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x), y))

# %%
train_ds = train_ds.map(    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf_data.AUTOTUNE,
)

# %% [markdown]
# ## Building the model
#
# Note we need to install graphviz on our device for this to work

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(128, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        units = 1
    else:
        units = num_classes

    x = layers.Dropout(0.25)(x)
    # We specify activation=None so as to return logits
    outputs = layers.Dense(units, activation=None)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
# Out:
# WARNING:tensorflow:From C:\Users\zupan\miniconda3\envs\ULPGC_FSI\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %% [markdown]
# ## Training the model
#
# - 3 epochs only because my laptop is not good enough for 25-50 epochs, even 3 is pushing it as I can barely run this as is.
# - The ModelCheckpoint callback is used to save the model's weights during training.
# -  Binary crossentropy loss is used, which is common for binary classification problems.
# - Binary accuracy is used as a metric to monitor the performance during training.

# %%
epochs = 3  # Even this takes hours to complete on my laptop

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.keras"),
]
# This is where I configure the model for training. It includes specifying the optimizer, loss function, and metrics. 
model.compile(
    optimizer=keras.optimizers.Adam(3e-4), # Adaptive Moment Estimation. Combination of RMSprop and Momentum.
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy(name="acc")],
)
#  It fits the model to the training data.
model.fit(
    train_ds,
    epochs=epochs,
    callbacks=callbacks,
    validation_data=val_ds,
)
# Out:
# Epoch 1/3
# WARNING:tensorflow:From C:\Users\zupan\miniconda3\envs\ULPGC_FSI\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 12/12 [==============================] - 717s 61s/step - loss: 0.7255 - acc: 0.5485 - val_loss: 0.6935 - val_acc: 0.5040
# Epoch 2/3
# 12/12 [==============================] - 807s 65s/step - loss: 0.6425 - acc: 0.6210 - val_loss: 0.6934 - val_acc: 0.5040
# Epoch 3/3
# 12/12 [==============================] - 844s 71s/step - loss: 0.6227 - acc: 0.6436 - val_loss: 0.6933 - val_acc: 0.5040

# %% [markdown]
# # Training complete
#
# But with 3 epoch and only 10% of the original images used the results are pretty terrible.

# %%
# Number of images to display
num_images = 9

# Create a subplot with the specified number of rows and columns
plt.figure(figsize=(12, 12))
rows = (num_images // 3) + 1
columns = 3

# Load and display each image
for i in range(1, num_images + 1):
    # Load the image
    img = keras.utils.load_img(f"PetImages/Cat/{i}.jpg", target_size=image_size)
    
    # Convert the image to a numpy array
    img_array = keras.utils.img_to_array(img)
    
    # Expand dimensions to create batch axis
    img_array = tf.expand_dims(img_array, 0)
    
    # Make predictions
    predictions = model.predict(img_array)
    score = float(tf.sigmoid(predictions[0][0]))
    
    # Display the image and prediction
    plt.subplot(rows, columns, i)
    plt.imshow(img)
    plt.title(f"Cat: {100 * (1 - score):.2f}%, Dog: {100 * score:.2f}%")
    plt.axis("off")

# Adjust layout to prevent clipping
plt.tight_layout()
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 55ms/step
